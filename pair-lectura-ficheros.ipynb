# %% [markdown]
# 1- Hacer las importaciones necesarias para abrir un archivo de tipo "csv" en Pandas.

# %%
import pandas as pd
import csv

# %% [markdown]
# 2- Abrir el archivo, creando un Dataframe. Aseguraros de que no incluye la columna "Unnamed: 0".

# %%
df_video_juegos = pd.read_csv("videogames.csv", index_col= 0)
df_video_juegos
# Out:
#                                       name  \
# 0                               Spider-Man
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4      https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
# ...                                                  ...     ...         ...
# 20798  https://www.imdb.com/title/tt3845606/?ref_=adv...  2014.0         NaN
# 20799  https://www.imdb.com/title/tt0790739/?ref_=adv...  2004.0         NaN
# 20800  https://www.imdb.com/title/tt5119948/?ref_=adv...  2015.0         NaN
# 20801  https://www.imdb.com/title/tt5142082/?ref_=adv...  2015.0         NaN
# 20802  https://www.imdb.com/title/tt10964974/?ref_=ad...  2020.0         NaN
#
#        rating   votes                                               plot  \
# 0         9.2  20,759  When a new villain threatens New York City, Pe...
# 1         9.7  35,703  Amidst the decline of the Wild West at the tur...
# 2         9.5  59,986  Three very different criminals team up for a s...
# 3         9.6  26,118  After wiping out the gods of Mount Olympus, Kr...
# 4         9.5  28,722  Thrown back into the dangerous underworld he'd...
# ...       ...     ...                                                ...
# 20798     NaN     NaN                                         Add a Plot
# 20799     NaN     NaN  Joseph gets kidnapped and it's the player's jo...
# 20800     NaN     NaN  A tech support man who uses a drone to investi...
# 20801     NaN     NaN  A young teenage girl and the ghost of a dead m...
# 20802     NaN     NaN  Kidnapped by an insane man and dragged into a ...
#
#        Action  Adventure  Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  \
# 0        True       True   False  False   False     True    False   False
# 1        True       True   False   True   False    False    False   False
# 2        True      False   False   True   False    False    False   False
# 3        True       True   False  False   False    False    False   False
# 4        True       True   False  False   False    False    False   False
# ...       ...        ...     ...    ...     ...      ...      ...     ...
# 20798   False      False   False  False   False    False    False   False
# 20799   False      False   False  False   False    False    False   False
# 20800   False      False   False  False   False    False    False   False
# 20801   False      False   False  False   False    False    False   False
# 20802   False      False   False  False   False    False    False   False
#
#        Thriller
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 20798      True
# 20799      True
# 20800      True
# 20801      True
# 20802      True
#
# [20803 rows x 16 columns]

# %% [markdown]
# 3- Una vez creado el Dataframe, muestra las 10 primeras filas.

# %%
df_video_juegos.head(10)
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
# 5     The Last of Us: Part II
# 6      Horizon Forbidden West
# 7              The Last of Us
# 8       Detroit: Become Human
# 9             Death Stranding
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
# 5  https://www.imdb.com/title/tt6298000/?ref_=adv...  2020.0           M
# 6  https://www.imdb.com/title/tt12496904/?ref_=ad...  2022.0           T
# 7  https://www.imdb.com/title/tt2140553/?ref_=adv...  2013.0           M
# 8  https://www.imdb.com/title/tt5158314/?ref_=adv...  2018.0           M
# 9  https://www.imdb.com/title/tt5807606/?ref_=adv...  2019.0           M
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# 2     9.5  59,986  Three very different criminals team up for a s...    True
# 3     9.6  26,118  After wiping out the gods of Mount Olympus, Kr...    True
# 4     9.5  28,722  Thrown back into the dangerous underworld he'd...    True
# 5     8.5  30,460  Five years after the events of The Last of Us,...    True
# 6     9.2   2,979  Aloy treks into an arcane region and faces new...    True
# 7     9.7  60,590  In a hostile, post-pandemic world, Joel and El...    True
# 8     9.2  16,907  Take control of three androids in their quest ...    True
# 9     8.8   8,136  Deliveryman Sam Porter must travel across a ra...    True
#
#    Adventure  Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  Thriller
# 0       True   False  False   False     True    False   False     False
# 1       True   False   True   False    False    False   False     False
# 2      False   False   True   False    False    False   False     False
# 3       True   False  False   False    False    False   False     False
# 4       True   False  False   False    False    False   False     False
# 5       True   False  False   False    False    False   False     False
# 6       True   False  False   False    False     True   False     False
# 7       True   False  False   False    False    False   False     False
# 8       True   False  False   False    False    False   False     False
# 9       True   False  False   False    False    False   False     False

# %% [markdown]
# 4- ¿Cúal es el último índice que tenemos en el Dataframe?

# %%
df_video_juegos.tail(1)
# Out:
#           name                                                url    year  \
# 20802  Cryptic  https://www.imdb.com/title/tt10964974/?ref_=ad...  2020.0
#
#       certificate  rating votes  \
# 20802         NaN     NaN   NaN
#
#                                                     plot  Action  Adventure  \
# 20802  Kidnapped by an insane man and dragged into a ...   False      False
#
#        Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  Thriller
# 20802   False  False   False    False    False   False      True

# %% [markdown]
# 5- Mostrar 15 filas aleatorias.

# %%
df_video_juegos.sample(15)
# Out:
#                                                   name  \
# 5326                                Cloudberry Kingdom
# 19443                                     Resistance 2
# 6067                               Soldier Girl Amazon
# 9518                                     Tail Gunner 2
# 16299                                        NFL Blitz
# 2994                      Steel Battalion: Heavy Armor
# 16057                                         Gangland
# 4061                         Frontline Commando: D-Day
# 2543           Destroy All Humans! Big Willy Unleashed
# 2107                                   Metroid: Fusion
# 20398                                       Earth 2160
# 11467  The Legend of Heroes: Trails in the Sky the 3rd
# 1873                             Punishing: Gray Raven
# 5960                                     Critical Path
# 9005             Rupan sansei: Densetsu no hihou o oe!
#
#                                                      url    year certificate  \
# 5326   https://www.imdb.com/title/tt2543088/?ref_=adv...  2013.0           T
# 19443  https://www.imdb.com/title/tt1223886/?ref_=adv...  2008.0           M
# 6067   https://www.imdb.com/title/tt2153552/?ref_=adv...  1986.0         NaN
# 9518   https://www.imdb.com/title/tt2101454/?ref_=adv...  1980.0         NaN
# 16299  https://www.imdb.com/title/tt0292137/?ref_=adv...  1997.0           E
# 2994   https://www.imdb.com/title/tt2378950/?ref_=adv...  2012.0           M
# 16057  https://www.imdb.com/title/tt0406797/?ref_=adv...  2004.0           M
# 4061   https://www.imdb.com/title/tt6684858/?ref_=adv...  2013.0         NaN
# 2543   https://www.imdb.com/title/tt1078189/?ref_=adv...  2008.0           T
# 2107   https://www.imdb.com/title/tt0349818/?ref_=adv...  2002.0           E
# 20398  https://www.imdb.com/title/tt8674646/?ref_=adv...  2005.0         NaN
# 11467  https://www.imdb.com/title/tt5345610/?ref_=adv...  2007.0           T
# 1873   https://www.imdb.com/title/tt13681774/?ref_=ad...  2019.0         NaN
# 5960   https://www.imdb.com/title/tt0157493/?ref_=adv...  1994.0         NaN
# 9005   https://www.imdb.com/title/tt0903971/?ref_=adv...  1994.0         NaN
#
#        rating  votes                                               plot  \
# 5326      4.2     26  The Orb resurfaces and the old, maniacal, vill...
# 19443     7.9  1,290  The Chimera have launched a full scale invasio...
# 6067      NaN    NaN                                         Add a Plot
# 9518      NaN    NaN                                         Add a Plot
# 16299     8.1     64  Football has been a major staple of arcade vid...
# 2994      2.3     40  2082. Pilot the most powerful weapon on the ba...
# 16057     6.0     26                                         Add a Plot
# 4061      NaN    NaN                                         Add a Plot
# 2543      6.7     79  Crypto and Pox have started a fast food restau...
# 2107      8.4    822  After the Metroids were considered to be wiped...
# 20398     NaN    NaN                                         Add a Plot
# 11467     7.4     34  Half a year after the events of Trails in the ...
# 1873      7.6      5  The story of game takes place in a post-apocal...
# 5960      6.5     12  After an apocalyptic event, a surviving comman...
# 9005      NaN    NaN    Lupin is in search for the "Fountain of Youth".
#
#        Action  Adventure  Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  \
# 5326     True      False   False  False   False    False    False   False
# 19443    True      False   False  False   False    False    False    True
# 6067     True       True   False  False   False     True    False   False
# 9518     True      False   False  False   False    False    False    True
# 16299   False      False   False  False    True    False    False   False
# 2994     True      False   False  False   False    False    False    True
# 16057    True      False   False   True   False    False    False   False
# 4061     True      False   False  False   False    False    False   False
# 2543     True       True    True  False   False    False    False   False
# 2107     True       True   False  False   False    False     True   False
# 20398   False      False   False  False   False    False    False    True
# 11467   False       True   False  False   False     True    False   False
# 1873     True      False   False  False   False    False    False    True
# 5960     True       True   False  False   False    False    False    True
# 9005     True       True   False  False   False     True    False   False
#
#        Thriller
# 5326      False
# 19443      True
# 6067      False
# 9518      False
# 16299     False
# 2994       True
# 16057     False
# 4061      False
# 2543      False
# 2107      False
# 20398     False
# 11467     False
# 1873      False
# 5960      False
# 9005      False

# %% [markdown]
# 6- Crea una lista con el nombre de las columnas.

# %%
df_video_juegos.columns
# Out:
# Index(['name', 'url', 'year', 'certificate', 'rating', 'votes', 'plot',
#        'Action', 'Adventure', 'Comedy', 'Crime', 'Family', 'Fantasy',
#        'Mystery', 'Sci-Fi', 'Thriller'],
#       dtype='object')

# %% [markdown]
# 7- Guardar el Dataframe en formato Excel y después crear un Dataframe con el Excel. ¿EL Dataframe es similar al que teníais antes?

# %%
df_video_juegos.to_excel('video_juegos.xlsx')

# %%
df_excel_juegos = pd.read_excel('video_juegos.xlsx', index_col= 0)

# %%
df_excel_juegos
# Out:
#                                       name  \
# 0                               Spider-Man
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4      https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
# ...                                                  ...     ...         ...
# 20798  https://www.imdb.com/title/tt3845606/?ref_=adv...  2014.0         NaN
# 20799  https://www.imdb.com/title/tt0790739/?ref_=adv...  2004.0         NaN
# 20800  https://www.imdb.com/title/tt5119948/?ref_=adv...  2015.0         NaN
# 20801  https://www.imdb.com/title/tt5142082/?ref_=adv...  2015.0         NaN
# 20802  https://www.imdb.com/title/tt10964974/?ref_=ad...  2020.0         NaN
#
#        rating   votes                                               plot  \
# 0         9.2  20,759  When a new villain threatens New York City, Pe...
# 1         9.7  35,703  Amidst the decline of the Wild West at the tur...
# 2         9.5  59,986  Three very different criminals team up for a s...
# 3         9.6  26,118  After wiping out the gods of Mount Olympus, Kr...
# 4         9.5  28,722  Thrown back into the dangerous underworld he'd...
# ...       ...     ...                                                ...
# 20798     NaN     NaN                                         Add a Plot
# 20799     NaN     NaN  Joseph gets kidnapped and it's the player's jo...
# 20800     NaN     NaN  A tech support man who uses a drone to investi...
# 20801     NaN     NaN  A young teenage girl and the ghost of a dead m...
# 20802     NaN     NaN  Kidnapped by an insane man and dragged into a ...
#
#        Action  Adventure  Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  \
# 0        True       True   False  False   False     True    False   False
# 1        True       True   False   True   False    False    False   False
# 2        True      False   False   True   False    False    False   False
# 3        True       True   False  False   False    False    False   False
# 4        True       True   False  False   False    False    False   False
# ...       ...        ...     ...    ...     ...      ...      ...     ...
# 20798   False      False   False  False   False    False    False   False
# 20799   False      False   False  False   False    False    False   False
# 20800   False      False   False  False   False    False    False   False
# 20801   False      False   False  False   False    False    False   False
# 20802   False      False   False  False   False    False    False   False
#
#        Thriller
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 20798      True
# 20799      True
# 20800      True
# 20801      True
# 20802      True
#
# [20803 rows x 16 columns]

# %% [markdown]
# 8- Muestra la "info" del Dataframe.

# %%
df_excel_juegos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20803 entries, 0 to 20802
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         20803 non-null  object
#  1   url          20803 non-null  object
#  2   year         20536 non-null  float64
#  3   certificate  7903 non-null   object
#  4   rating       11600 non-null  float64
#  5   votes        11600 non-null  object
#  6   plot         20803 non-null  object
#  7   Action       20803 non-null  bool
#  8   Adventure    20803 non-null  bool
#  9   Comedy       20803 non-null  bool
#  10  Crime        20803 non-null  bool
#  11  Family       20803 non-null  bool
#  12  Fantasy      20803 non-null  bool
#  13  Mystery      20803 non-null  bool
#  14  Sci-Fi       20803 non-null  bool
#  15  Thriller     20803 non-null  bool
# dtypes: bool(9), float64(2), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# 9- ¿Tiene nulos o duplicados?

# %%
df_excel_juegos.isnull()
# Out:
#         name    url   year  certificate  rating  votes   plot  Action  \
# 0      False  False  False        False   False  False  False   False
# 1      False  False  False        False   False  False  False   False
# 2      False  False  False        False   False  False  False   False
# 3      False  False  False        False   False  False  False   False
# 4      False  False  False        False   False  False  False   False
# ...      ...    ...    ...          ...     ...    ...    ...     ...
# 20798  False  False  False         True    True   True  False   False
# 20799  False  False  False         True    True   True  False   False
# 20800  False  False  False         True    True   True  False   False
# 20801  False  False  False         True    True   True  False   False
# 20802  False  False  False         True    True   True  False   False
#
#        Adventure  Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  Thriller
# 0          False   False  False   False    False    False   False     False
# 1          False   False  False   False    False    False   False     False
# 2          False   False  False   False    False    False   False     False
# 3          False   False  False   False    False    False   False     False
# 4          False   False  False   False    False    False   False     False
# ...          ...     ...    ...     ...      ...      ...     ...       ...
# 20798      False   False  False   False    False    False   False     False
# 20799      False   False  False   False    False    False   False     False
# 20800      False   False  False   False    False    False   False     False
# 20801      False   False  False   False    False    False   False     False
# 20802      False   False  False   False    False    False   False     False
#
# [20803 rows x 16 columns]

# %%
df_excel_juegos.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20798    False
# 20799    False
# 20800    False
# 20801    False
# 20802    False
# Length: 20803, dtype: bool

# %% [markdown]
# 10 -Obtener la descripción del Dataframe, tanto de las columnas numéricas cómo de las de tipo "object". Explorar el resultado y sacar unas mínimas comclusiones sobre los datos que habéis obtenido.

# %%
df_excel_juegos.describe(include='object')
# Out:
#               name                                                url  \
# count        20803                                              20803
# unique       19714                                              20157
# top     Spider-Man  https://www.imdb.com/title/tt5807780/?ref_=adv...
# freq             9                                                  4
#
#        certificate  votes        plot
# count         7903  11600       20803
# unique          21   1905       11276
# top              T      7  Add a Plot
# freq          2474    318        8874

# %% [markdown]
# 11 - Finalmente, guarda el Dataframe en formato "csv" con un nombre diferente del original.

# %%
df_excel_juegos.to_csv('excel_video_juegos.csv')
